# %% [markdown]
# # Entrenar y cuantizar con MediaPipe Model Maker
#
# Ejecuta el script `mediapipe_quan_simple.py` desde este notebook, usando las rutas relativas del proyecto.

# %%
import os
from pathlib import Path

# Ajusta el directorio de trabajo al del notebook/script
PROJECT_ROOT = Path(__file__).resolve().parent if "__file__" in globals() else Path().resolve()
os.chdir(PROJECT_ROOT)
print("Working directory:", Path.cwd())

# Opcional: valida que el dataset esté donde el script lo espera
dataset_dir = PROJECT_ROOT / "Hard Hat Sample.v2-augmented-416x416.voc"
print("Dataset exists:", dataset_dir.exists())
print("Dataset path:", dataset_dir)
# Out:
# Working directory: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si
# Dataset exists: True
# Dataset path: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/Hard Hat Sample.v2-augmented-416x416.voc

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
print("GPUs disponibles:", gpus)
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.debugging.set_log_device_placement(True)
    print("Log de colocación de dispositivos activado.")
else:
    print("No se detectó GPU; se usará CPU.")
# Out:
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Log de colocación de dispositivos activado.

# %%
# Ejecuta el script principal
# !python mediapipe_quan_simple.py
# Out:
# 2025-11-27 13:53:21.417713: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-27 13:53:21.417743: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-27 13:53:21.427172: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Creando estructura de cache...
# Cargando dataset...
# Train dataset cargado
# Val dataset cargado
# Clases: ['background', 'head', 'helmet', 'person']
#
# === PASO 1: Entrenando modelo FLOAT ===
# Using existing files at /tmp/model_maker/object_detector/mobilenetv2_i256
# Model: "retina_net_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net (MobileNet)      {'2': (None, 64, 64, 24   2257984
#                              ),
#                               '3': (None, 32, 32, 32
#                              ),
#                               '4': (None, 16, 16, 96
#                              ),
#                               '5': (None, 8, 8, 320)
#                              , '6': (None, 8, 8, 128
#                              0)}
#
#  fpn (FPN)                   {'5': (None, 8, 8, 128)   149056
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator (MultilevelDetectionG
#  enerator)
#
#  retina_net_head (RetinaNet  ({'3': (None, 32, 32, 3   173384
#  Head)                       6),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 2580424 (9.84 MB)
# Trainable params: 2534792 (9.67 MB)
# Non-trainable params: 45632 (178.25 KB)
# _________________________________________________________________
# Epoch 1/30
# 26/26 [==============================] - 49s 426ms/step - total_loss: 4.2822 - cls_loss: 3.7149 - box_loss: 0.0102 - model_loss: 4.2272 - val_total_loss: 1.5360 - val_cls_loss: 1.1531 - val_box_loss: 0.0066 - val_model_loss: 1.4810
# Epoch 2/30
# 26/26 [==============================] - 5s 190ms/step - total_loss: 1.4453 - cls_loss: 1.0175 - box_loss: 0.0075 - model_loss: 1.3903 - val_total_loss: 1.2598 - val_cls_loss: 0.9619 - val_box_loss: 0.0049 - val_model_loss: 1.2049
# Epoch 3/30
# 26/26 [==============================] - 5s 191ms/step - total_loss: 1.1272 - cls_loss: 0.8001 - box_loss: 0.0054 - model_loss: 1.0722 - val_total_loss: 0.9538 - val_cls_loss: 0.6939 - val_box_loss: 0.0041 - val_model_loss: 0.8988
# Epoch 4/30
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0
# 26/26 [==============================] - 6s 216ms/step - total_loss: 0.3135 - cls_loss: 0.1779 - box_loss: 0.0016 - model_loss: 0.2586 - val_total_loss: 0.5635 - val_cls_loss: 0.3082 - val_box_loss: 0.0040 - val_model_loss: 0.5085
# Epoch 28/30
# 26/26 [==============================] - 6s 209ms/step - total_loss: 0.3160 - cls_loss: 0.1795 - box_loss: 0.0016 - model_loss: 0.2610 - val_total_loss: 0.5742 - val_cls_loss: 0.2965 - val_box_loss: 0.0045 - val_model_loss: 0.5192
# Epoch 29/30
# 26/26 [==============================] - 6s 217ms/step - total_loss: 0.3114 - cls_loss: 0.1756 - box_loss: 0.0016 - model_loss: 0.2564 - val_total_loss: 0.5876 - val_cls_loss: 0.3170 - val_box_loss: 0.0043 - val_model_loss: 0.5327
# Epoch 30/30
# 26/26 [==============================] - 6s 219ms/step - total_loss: 0.3324 - cls_loss: 0.1896 - box_loss: 0.0018 - model_loss: 0.2775 - val_total_loss: 0.5678 - val_cls_loss: 0.3012 - val_box_loss: 0.0042 - val_model_loss: 0.5129
#
# Evaluando modelo float...
# 20/20 [==============================] - 2s 25ms/step - total_loss: 0.5727 - cls_loss: 0.3071 - box_loss: 0.0042 - model_loss: 0.5178
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.313
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.700
# Float model - Loss:  [0.5727021098136902, 0.3070719242095947, 0.004213572014123201, 0.5177505016326904]
# Métricas: {'AP': 0.253193, 'AP50': 0.54736704, 'AP75': 0.14848876, 'APs': 0.24290429, 'APm': 0.26495448, 'APl': 0.6792904, 'ARmax1': 0.087037034, 'ARmax10': 0.31333333, 'ARmax100': 0.31703705, 'ARs': 0.25555557, 'ARm': 0.32740742, 'ARl': 0.7}
#   AP: 0.2531929910182953
#   AP50: 0.5473670363426208
#   AP75: 0.14848875999450684
#   APs: 0.24290429055690765
#   APm: 0.26495447754859924
#   APl: 0.6792904138565063
#   ARmax1: 0.08703703433275223
#   ARmax10: 0.31333333253860474
#   ARmax100: 0.31703704595565796
#   ARs: 0.25555557012557983
#   ARm: 0.3274074196815491
#   ARl: 0.699999988079071
# Exporting a floating point model
# 2025-11-27 13:59:05.000084: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-27 13:59:05.000120: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# Modelo float exportado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_float/model_float.tflite
#
# === PASO 2: Quantization Aware Training ===
# Restaurando checkpoint float...
# Using existing files at /tmp/model_maker/object_detector/mobilenetv2_i256
# Model: "retina_net_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net_1 (MobileNet)    {'2': (None, 64, 64, 24   2257984
#                              ),
#                               '3': (None, 32, 32, 32
#                              ),
#                               '4': (None, 16, 16, 96
#                              ),
#                               '5': (None, 8, 8, 320)
#                              , '6': (None, 8, 8, 128
#                              0)}
#
#  fpn_1 (FPN)                 {'5': (None, 8, 8, 128)   149056
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator_2 (MultilevelDetectio
#  nGenerator)
#
#  retina_net_head_1 (RetinaN  ({'3': (None, 32, 32, 3   173384
#  etHead)                     6),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 2580424 (9.84 MB)
# Trainable params: 2534792 (9.67 MB)
# Non-trainable params: 45632 (178.25 KB)
# _________________________________________________________________
# Iniciando QAT...
# Epoch 1/30
# 52/52 [==============================] - 81s 487ms/step - total_loss: 1.6027 - cls_loss: 0.8325 - box_loss: 0.0154 - model_loss: 1.6027 - val_total_loss: 2.1026 - val_cls_loss: 1.4653 - val_box_loss: 0.0127 - val_model_loss: 2.1026
# Epoch 2/30
# 52/52 [==============================] - 15s 292ms/step - total_loss: 0.8682 - cls_loss: 0.5177 - box_loss: 0.0070 - model_loss: 0.8682 - val_total_loss: 1.8031 - val_cls_loss: 1.2880 - val_box_loss: 0.0103 - val_model_loss: 1.8031
# Epoch 3/30
# 52/52 [==============================] - 15s 295ms/step - total_loss: 0.7641 - cls_loss: 0.4555 - box_loss: 0.0062 - model_loss: 0.7641 - val_total_loss: 1.5650 - val_cls_loss: 1.1429 - val_box_loss: 0.0084 - val_model_loss: 1.5650
# Epoch 4/30
# 52/52 [==============================] - 15s 297ms/step - total_loss: 0.6954 - cls_loss: 0.4112 - box_loss: 0.0057 - model_loss: 0.6954 - val_total_loss: 1.3216 - val_cls_loss: 0.9737 - val_box_loss: 0.0070 - val_model_loss: 1.3216
# Epoch 5/30
# 52/52 [==============================] - 16s 312ms/step - total_loss: 0.6677 - cls_loss: 0.4055 - box_loss: 0.0052 - model_loss: 0.6677 - val_total_loss: 1.1204 - val_cls_loss: 0.8263 - val_box_loss: 0.0059 - val_model_loss: 1.1204
# Epoch 6/30
# 52/52 [==============================] - 16s 305ms/step - total_loss: 0.6268 - cls_loss: 0.3773 - box_loss: 0.0050 - model_loss: 0.6268 - val_total_loss: 0.9478 - val_cls_loss: 0.6801 - val_box_loss: 0.0054 - val_model_loss: 0.9478
# Epoch 7/30
# 52/52 [==============================] - 16s 298ms/step - total_loss: 0.6070 - cls_loss: 0.3743 - box_loss: 0.0047 - model_loss: 0.6070 - val_total_loss: 0.8205 - val_cls_loss: 0.5578 - val_box_loss: 0.0053 - val_model_loss: 0.8205
# Epoch 8/30
# 52/52 [==============================] - 16s 302ms/step - total_loss: 0.5937 - cls_loss: 0.3609 - box_loss: 0.0047 - model_loss: 0.5937 - val_total_loss: 0.7105 - val_cls_loss: 0.4709 - val_box_loss: 0.0048 - val_model_loss: 0.7105
# Epoch 9/30
# 52/52 [==============================] - 15s 298ms/step - total_loss: 0.5954 - cls_loss: 0.3621 - box_loss: 0.0047 - model_loss: 0.5954 - val_total_loss: 0.6562 - val_cls_loss: 0.4156 - val_box_loss: 0.0048 - val_model_loss: 0.6562
# Epoch 10/30
# 52/52 [==============================] - 17s 326ms/step - total_loss: 0.5978 - cls_loss: 0.3624 - box_loss: 0.0047 - model_loss: 0.5978 - val_total_loss: 0.6278 - val_cls_loss: 0.3902 - val_box_loss: 0.0048 - val_model_loss: 0.6278
# Epoch 11/30
# 52/52 [==============================] - 16s 302ms/step - total_loss: 0.5881 - cls_loss: 0.3568 - box_loss: 0.0046 - model_loss: 0.5881 - val_total_loss: 0.6081 - val_cls_loss: 0.3738 - val_box_loss: 0.0047 - val_model_loss: 0.6081
# Epoch 12/30
# 52/52 [==============================] - 16s 303ms/step - total_loss: 0.5609 - cls_loss: 0.3502 - box_loss: 0.0042 - model_loss: 0.5609 - val_total_loss: 0.6069 - val_cls_loss: 0.3702 - val_box_loss: 0.0047 - val_model_loss: 0.6069
# Epoch 13/30
# 52/52 [==============================] - 16s 303ms/step - total_loss: 0.5859 - cls_loss: 0.3534 - box_loss: 0.0046 - model_loss: 0.5859 - val_total_loss: 0.6038 - val_cls_loss: 0.3704 - val_box_loss: 0.0047 - val_model_loss: 0.6038
# Epoch 14/30
# 52/52 [==============================] - 16s 302ms/step - total_loss: 0.5552 - cls_loss: 0.3471 - box_loss: 0.0042 - model_loss: 0.5552 - val_total_loss: 0.5991 - val_cls_loss: 0.3677 - val_box_loss: 0.0046 - val_model_loss: 0.5991
# Epoch 15/30
# 52/52 [==============================] - 16s 304ms/step - total_loss: 0.5926 - cls_loss: 0.3638 - box_loss: 0.0046 - model_loss: 0.5926 - val_total_loss: 0.5926 - val_cls_loss: 0.3659 - val_box_loss: 0.0045 - val_model_loss: 0.5926
# Epoch 16/30
# 52/52 [==============================] - 16s 301ms/step - total_loss: 0.5922 - cls_loss: 0.3594 - box_loss: 0.0047 - model_loss: 0.5922 - val_total_loss: 0.5922 - val_cls_loss: 0.3637 - val_box_loss: 0.0046 - val_model_loss: 0.5922
# Epoch 17/30
# 52/52 [==============================] - 16s 306ms/step - total_loss: 0.5604 - cls_loss: 0.3437 - box_loss: 0.0043 - model_loss: 0.5604 - val_total_loss: 0.5974 - val_cls_loss: 0.3645 - val_box_loss: 0.0047 - val_model_loss: 0.5974
# Epoch 18/30
# 52/52 [==============================] - 16s 310ms/step - total_loss: 0.5920 - cls_loss: 0.3582 - box_loss: 0.0047 - model_loss: 0.5920 - val_total_loss: 0.6055 - val_cls_loss: 0.3691 - val_box_loss: 0.0047 - val_model_loss: 0.6055
# Epoch 19/30
# 52/52 [==============================] - 16s 306ms/step - total_loss: 0.5754 - cls_loss: 0.3553 - box_loss: 0.0044 - model_loss: 0.5754 - val_total_loss: 0.5966 - val_cls_loss: 0.3662 - val_box_loss: 0.0046 - val_model_loss: 0.5966
# Epoch 20/30
# 52/52 [==============================] - 16s 301ms/step - total_loss: 0.6047 - cls_loss: 0.3661 - box_loss: 0.0048 - model_loss: 0.6047 - val_total_loss: 0.6031 - val_cls_loss: 0.3653 - val_box_loss: 0.0048 - val_model_loss: 0.6031
# Epoch 21/30
# 52/52 [==============================] - 16s 307ms/step - total_loss: 0.5939 - cls_loss: 0.3516 - box_loss: 0.0048 - model_loss: 0.5939 - val_total_loss: 0.6001 - val_cls_loss: 0.3647 - val_box_loss: 0.0047 - val_model_loss: 0.6001
# Epoch 22/30
# 52/52 [==============================] - 16s 310ms/step - total_loss: 0.6380 - cls_loss: 0.3881 - box_loss: 0.0050 - model_loss: 0.6380 - val_total_loss: 0.6002 - val_cls_loss: 0.3652 - val_box_loss: 0.0047 - val_model_loss: 0.6002
# Epoch 23/30
# 52/52 [==============================] - 16s 309ms/step - total_loss: 0.5948 - cls_loss: 0.3645 - box_loss: 0.0046 - model_loss: 0.5948 - val_total_loss: 0.6001 - val_cls_loss: 0.3664 - val_box_loss: 0.0047 - val_model_loss: 0.6001
# Epoch 24/30
# 52/52 [==============================] - 16s 300ms/step - total_loss: 0.5772 - cls_loss: 0.3460 - box_loss: 0.0046 - model_loss: 0.5772 - val_total_loss: 0.5999 - val_cls_loss: 0.3646 - val_box_loss: 0.0047 - val_model_loss: 0.5999
# Epoch 25/30
# 52/52 [==============================] - 16s 305ms/step - total_loss: 0.5732 - cls_loss: 0.3509 - box_loss: 0.0044 - model_loss: 0.5732 - val_total_loss: 0.6009 - val_cls_loss: 0.3676 - val_box_loss: 0.0047 - val_model_loss: 0.6009
# Epoch 26/30
# 52/52 [==============================] - 16s 303ms/step - total_loss: 0.5813 - cls_loss: 0.3545 - box_loss: 0.0045 - model_loss: 0.5813 - val_total_loss: 0.5996 - val_cls_loss: 0.3648 - val_box_loss: 0.0047 - val_model_loss: 0.5996
# Epoch 27/30
# 52/52 [==============================] - 16s 302ms/step - total_loss: 0.5390 - cls_loss: 0.3350 - box_loss: 0.0041 - model_loss: 0.5390 - val_total_loss: 0.5948 - val_cls_loss: 0.3650 - val_box_loss: 0.0046 - val_model_loss: 0.5948
# Epoch 28/30
# 52/52 [==============================] - 16s 303ms/step - total_loss: 0.5767 - cls_loss: 0.3508 - box_loss: 0.0045 - model_loss: 0.5767 - val_total_loss: 0.5975 - val_cls_loss: 0.3660 - val_box_loss: 0.0046 - val_model_loss: 0.5975
# Epoch 29/30
# 52/52 [==============================] - 16s 304ms/step - total_loss: 0.5675 - cls_loss: 0.3463 - box_loss: 0.0044 - model_loss: 0.5675 - val_total_loss: 0.6011 - val_cls_loss: 0.3683 - val_box_loss: 0.0047 - val_model_loss: 0.6011
# Epoch 30/30
# 52/52 [==============================] - 16s 309ms/step - total_loss: 0.5750 - cls_loss: 0.3473 - box_loss: 0.0046 - model_loss: 0.5750 - val_total_loss: 0.5984 - val_cls_loss: 0.3648 - val_box_loss: 0.0047 - val_model_loss: 0.5984
#
# Evaluando modelo cuantizado...
# 20/20 [==============================] - 2s 69ms/step - total_loss: 0.6200 - cls_loss: 0.3799 - box_loss: 0.0048 - model_loss: 0.6200
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.412
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.313
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617
# QAT model - Loss:  [0.6199787259101868, 0.37994855642318726, 0.004800604190677404, 0.6199787259101868]
# Métricas: {'AP': 0.19812065, 'AP50': 0.4123604, 'AP75': 0.13172743, 'APs': 0.09820128, 'APm': 0.21055993, 'APl': 0.5920792, 'ARmax1': 0.08111111, 'ARmax10': 0.25333333, 'ARmax100': 0.29555556, 'ARs': 0.21111111, 'ARm': 0.3125926, 'ARl': 0.6166667}
#
# Exportando modelo cuantizado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_qat.tflite
# Exporting a qat int8 model
# 2025-11-27 14:10:35.588898: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-27 14:10:35.597186: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# ¡Entrenamiento completo!
#
# Resumen:
# - Modelo float: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_float/model_float.tflite
# - Modelo cuantizado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_qat.tflite
