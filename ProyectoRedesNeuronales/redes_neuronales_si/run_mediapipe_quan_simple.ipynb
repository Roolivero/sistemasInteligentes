# %% [markdown]
# # Entrenar y cuantizar con MediaPipe Model Maker
#
# Ejecuta el script `mediapipe_quan_simple.py` desde este notebook, usando las rutas relativas del proyecto.

# %%
import os
from pathlib import Path

# Ajusta el directorio de trabajo al del notebook/script
PROJECT_ROOT = Path(__file__).resolve().parent if "__file__" in globals() else Path().resolve()
os.chdir(PROJECT_ROOT)
print("Working directory:", Path.cwd())

# Opcional: valida que el dataset esté donde el script lo espera
dataset_dir = PROJECT_ROOT / "Hard Hat Sample.v2-augmented-416x416.voc"
print("Dataset exists:", dataset_dir.exists())
print("Dataset path:", dataset_dir)
# Out:
# Working directory: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si
# Dataset exists: True
# Dataset path: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/Hard Hat Sample.v2-augmented-416x416.voc

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
print("GPUs disponibles:", gpus)
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.debugging.set_log_device_placement(True)
    print("Log de colocación de dispositivos activado.")
else:
    print("No se detectó GPU; se usará CPU.")
# Out:
# 2025-11-24 18:46:38.219268: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-24 18:46:38.219293: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-24 18:46:38.219310: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-24 18:46:38.224435: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPUs disponibles: []
# No se detectó GPU; se usará CPU.
# 2025-11-24 18:46:41.193160: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
# Ejecuta el script principal
# !python mediapipe_quan_simple.py
# Out:
# 2025-11-24 18:46:41.492077: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-24 18:46:41.492104: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-24 18:46:41.492129: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# ^C
# Traceback (most recent call last):
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/mediapipe_quan_simple.py", line 6, in <module>
#     from mediapipe_model_maker import object_detector
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe_model_maker/__init__.py", line 20, in <module>
#     from mediapipe_model_maker.python.vision import image_classifier
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe_model_maker/python/vision/image_classifier/__init__.py", line 18, in <module>
#     from mediapipe_model_maker.python.vision.image_classifier import image_classifier
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe_model_maker/python/vision/image_classifier/image_classifier.py", line 31, in <module>
#     from mediapipe.tasks.python.metadata.metadata_writers import image_classifier as image_classifier_writer
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe/__init__.py", line 17, in <module>
#     import mediapipe.tasks.python as tasks
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe/tasks/python/__init__.py", line 17, in <module>
#     from . import audio
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe/tasks/python/audio/__init__.py", line 18, in <module>
#     import mediapipe.tasks.python.audio.audio_classifier
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe/tasks/python/audio/audio_classifier.py", line 26, in <module>
#     from mediapipe.tasks.python.audio.core import base_audio_task_api
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe/tasks/python/audio/core/base_audio_task_api.py", line 23, in <module>
#     from mediapipe.tasks.python.audio.core import audio_record
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/mediapipe/tasks/python/audio/core/audio_record.py", line 19, in <module>
#     import sounddevice as sd
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/sounddevice.py", line 2871, in <module>
#     _initialize()
#   File "/mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/sounddevice.py", line 2835, in _initialize
#     _check(_lib.Pa_Initialize(), 'Error initializing PortAudio')
# KeyboardInterrupt
