# %% [markdown]
# # Entrenar y cuantizar con MediaPipe Model Maker
#
# Ejecuta el script `mediapipe_quan_simple.py` desde este notebook, usando las rutas relativas del proyecto.

# %%
import os
from pathlib import Path

# Ajusta el directorio de trabajo al del notebook/script
PROJECT_ROOT = Path(__file__).resolve().parent if "__file__" in globals() else Path().resolve()
os.chdir(PROJECT_ROOT)
print("Working directory:", Path.cwd())

# Opcional: valida que el dataset esté donde el script lo espera
dataset_dir = PROJECT_ROOT / "Hard Hat Sample.v2-augmented-416x416.voc"
print("Dataset exists:", dataset_dir.exists())
print("Dataset path:", dataset_dir)
# Out:
# Working directory: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si
# Dataset exists: True
# Dataset path: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/Hard Hat Sample.v2-augmented-416x416.voc

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
print("GPUs disponibles:", gpus)
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.debugging.set_log_device_placement(True)
    print("Log de colocación de dispositivos activado.")
else:
    print("No se detectó GPU; se usará CPU.")
# Out:
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Log de colocación de dispositivos activado.

# %%
# Ejecuta el script principal
# !python mediapipe_quan_simple.py
# Out:
# 2025-11-24 23:26:16.923703: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-24 23:26:16.923732: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-24 23:26:16.923753: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Creando estructura de cache...
# Cargando dataset...
# Train dataset cargado
# Val dataset cargado
# Clases: ['background', 'head', 'helmet', 'person']
#
# === PASO 1: Entrenando modelo FLOAT ===
# Using existing files at /tmp/model_maker/object_detector/mobilenetv2_i256
# Model: "retina_net_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net (MobileNet)      {'2': (None, 64, 64, 24   2257984
#                              ),
#                               '3': (None, 32, 32, 32
#                              ),
#                               '4': (None, 16, 16, 96
#                              ),
#                               '5': (None, 8, 8, 320)
#                              , '6': (None, 8, 8, 128
#                              0)}
#
#  fpn (FPN)                   {'5': (None, 8, 8, 128)   149056
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator (MultilevelDetectionG
#  enerator)
#
#  retina_net_head (RetinaNet  ({'3': (None, 32, 32, 3   173384
#  Head)                       6),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 2580424 (9.84 MB)
# Trainable params: 2534792 (9.67 MB)
# Non-trainable params: 45632 (178.25 KB)
# _________________________________________________________________
# Epoch 1/15
# 26/26 [==============================] - 45s 411ms/step - total_loss: 2.7427 - cls_loss: 2.1893 - box_loss: 0.0100 - model_loss: 2.6877 - val_total_loss: 1.4388 - val_cls_loss: 1.0960 - val_box_loss: 0.0058 - val_model_loss: 1.3838
# Epoch 2/15
# 26/26 [==============================] - 5s 188ms/step - total_loss: 1.3253 - cls_loss: 0.9422 - box_loss: 0.0066 - model_loss: 1.2703 - val_total_loss: 1.0451 - val_cls_loss: 0.7644 - val_box_loss: 0.0045 - val_model_loss: 0.9901
# Epoch 3/15
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0
#   AP: 0.28736987709999084
#   AP50: 0.5380107164382935
#   AP75: 0.26467862725257874
#   APs: 0.190264031291008
#   APm: 0.30144327878952026
#   APl: 0.7387788891792297
#   ARmax1: 0.1814814805984497
#   ARmax10: 0.42888888716697693
#   ARmax100: 0.4444444477558136
#   ARs: 0.18888889253139496
#   ARm: 0.46444445848464966
#   ARl: 0.75
# Exporting a floating point model
# 2025-11-24 23:29:21.875512: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-24 23:29:21.875539: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# Modelo float exportado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_float/model_float.tflite
#
# === PASO 2: Quantization Aware Training ===
# Restaurando checkpoint float...
# Using existing files at /tmp/model_maker/object_detector/mobilenetv2_i256
# Model: "retina_net_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net_1 (MobileNet)    {'2': (None, 64, 64, 24   2257984
#                              ),
#                               '3': (None, 32, 32, 32
#                              ),
#                               '4': (None, 16, 16, 96
#                              ),
#                               '5': (None, 8, 8, 320)
#                              , '6': (None, 8, 8, 128
#                              0)}
#
#  fpn_1 (FPN)                 {'5': (None, 8, 8, 128)   149056
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator_2 (MultilevelDetectio
#  nGenerator)
#
#  retina_net_head_1 (RetinaN  ({'3': (None, 32, 32, 3   173384
#  etHead)                     6),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 2580424 (9.84 MB)
# Trainable params: 2534792 (9.67 MB)
# Non-trainable params: 45632 (178.25 KB)
# _________________________________________________________________
# Iniciando QAT...
# Epoch 1/15
# 52/52 [==============================] - 66s 421ms/step - total_loss: 1.6529 - cls_loss: 0.8064 - box_loss: 0.0169 - model_loss: 1.6529 - val_total_loss: 2.0731 - val_cls_loss: 1.3823 - val_box_loss: 0.0138 - val_model_loss: 2.0731
# Epoch 2/15
# 52/52 [==============================] - 15s 285ms/step - total_loss: 0.9620 - cls_loss: 0.5513 - box_loss: 0.0082 - model_loss: 0.9620 - val_total_loss: 1.7991 - val_cls_loss: 1.2182 - val_box_loss: 0.0116 - val_model_loss: 1.7991
# Epoch 3/15
# 52/52 [==============================] - 15s 285ms/step - total_loss: 0.8586 - cls_loss: 0.5075 - box_loss: 0.0070 - model_loss: 0.8586 - val_total_loss: 1.5886 - val_cls_loss: 1.0973 - val_box_loss: 0.0098 - val_model_loss: 1.5886
# Epoch 4/15
# 52/52 [==============================] - 15s 287ms/step - total_loss: 0.7772 - cls_loss: 0.4737 - box_loss: 0.0061 - model_loss: 0.7772 - val_total_loss: 1.3861 - val_cls_loss: 0.9703 - val_box_loss: 0.0083 - val_model_loss: 1.3861
# Epoch 5/15
# 52/52 [==============================] - 15s 286ms/step - total_loss: 0.7322 - cls_loss: 0.4424 - box_loss: 0.0058 - model_loss: 0.7322 - val_total_loss: 1.1707 - val_cls_loss: 0.8141 - val_box_loss: 0.0071 - val_model_loss: 1.1707
# Epoch 6/15
# 52/52 [==============================] - 15s 286ms/step - total_loss: 0.7085 - cls_loss: 0.4311 - box_loss: 0.0055 - model_loss: 0.7085 - val_total_loss: 1.0143 - val_cls_loss: 0.6868 - val_box_loss: 0.0066 - val_model_loss: 1.0143
# Epoch 7/15
# 52/52 [==============================] - 15s 286ms/step - total_loss: 0.6878 - cls_loss: 0.4222 - box_loss: 0.0053 - model_loss: 0.6878 - val_total_loss: 0.9059 - val_cls_loss: 0.5805 - val_box_loss: 0.0065 - val_model_loss: 0.9059
# Epoch 8/15
# 52/52 [==============================] - 15s 287ms/step - total_loss: 0.6322 - cls_loss: 0.3906 - box_loss: 0.0048 - model_loss: 0.6322 - val_total_loss: 0.8195 - val_cls_loss: 0.5096 - val_box_loss: 0.0062 - val_model_loss: 0.8195
# Epoch 9/15
# 52/52 [==============================] - 15s 287ms/step - total_loss: 0.6615 - cls_loss: 0.4083 - box_loss: 0.0051 - model_loss: 0.6615 - val_total_loss: 0.7698 - val_cls_loss: 0.4694 - val_box_loss: 0.0060 - val_model_loss: 0.7698
# Epoch 10/15
# 52/52 [==============================] - 15s 287ms/step - total_loss: 0.6645 - cls_loss: 0.4095 - box_loss: 0.0051 - model_loss: 0.6645 - val_total_loss: 0.7428 - val_cls_loss: 0.4450 - val_box_loss: 0.0060 - val_model_loss: 0.7428
# Epoch 11/15
# 52/52 [==============================] - 15s 286ms/step - total_loss: 0.6539 - cls_loss: 0.4012 - box_loss: 0.0051 - model_loss: 0.6539 - val_total_loss: 0.7437 - val_cls_loss: 0.4337 - val_box_loss: 0.0062 - val_model_loss: 0.7437
# Epoch 12/15
# 52/52 [==============================] - 15s 286ms/step - total_loss: 0.6476 - cls_loss: 0.3983 - box_loss: 0.0050 - model_loss: 0.6476 - val_total_loss: 0.7225 - val_cls_loss: 0.4231 - val_box_loss: 0.0060 - val_model_loss: 0.7225
# Epoch 13/15
# 52/52 [==============================] - 15s 285ms/step - total_loss: 0.6489 - cls_loss: 0.3988 - box_loss: 0.0050 - model_loss: 0.6489 - val_total_loss: 0.7194 - val_cls_loss: 0.4236 - val_box_loss: 0.0059 - val_model_loss: 0.7194
# Epoch 14/15
# 52/52 [==============================] - 15s 286ms/step - total_loss: 0.6191 - cls_loss: 0.3837 - box_loss: 0.0047 - model_loss: 0.6191 - val_total_loss: 0.7238 - val_cls_loss: 0.4238 - val_box_loss: 0.0060 - val_model_loss: 0.7238
# Epoch 15/15
# 52/52 [==============================] - 15s 287ms/step - total_loss: 0.6282 - cls_loss: 0.3903 - box_loss: 0.0048 - model_loss: 0.6282 - val_total_loss: 0.7195 - val_cls_loss: 0.4237 - val_box_loss: 0.0059 - val_model_loss: 0.7195
#
# Evaluando modelo cuantizado...
# 20/20 [==============================] - 2s 59ms/step - total_loss: 0.7374 - cls_loss: 0.4375 - box_loss: 0.0060 - model_loss: 0.7374
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.600
# QAT model - Loss:  [0.7373648285865784, 0.43746811151504517, 0.005997934378683567, 0.7373648285865784]
# Métricas: {'AP': 0.14893308, 'AP50': 0.3527486, 'AP75': 0.108286254, 'APs': 0.06881757, 'APm': 0.14976561, 'APl': 0.55264026, 'ARmax1': 0.06888889, 'ARmax10': 0.29259259, 'ARmax100': 0.32074073, 'ARs': 0.07777778, 'ARm': 0.3351852, 'ARl': 0.6}
#
# Exportando modelo cuantizado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_qat.tflite
# Exporting a qat int8 model
# 2025-11-24 23:35:46.048081: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-24 23:35:46.048106: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# ¡Entrenamiento completo!
#
# Resumen:
# - Modelo float: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_float/model_float.tflite
# - Modelo cuantizado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_qat.tflite
