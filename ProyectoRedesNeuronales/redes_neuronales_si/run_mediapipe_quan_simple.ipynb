# %% [markdown]
# # Entrenar y cuantizar con MediaPipe Model Maker
#
# Ejecuta el script `mediapipe_quan_simple.py` desde este notebook, usando las rutas relativas del proyecto.

# %%
import os
from pathlib import Path

# Ajusta el directorio de trabajo al del notebook/script
PROJECT_ROOT = Path(__file__).resolve().parent if "__file__" in globals() else Path().resolve()
os.chdir(PROJECT_ROOT)
print("Working directory:", Path.cwd())

# Opcional: valida que el dataset esté donde el script lo espera
dataset_dir = PROJECT_ROOT / "Hard Hat Sample.v2-augmented-416x416.voc"
print("Dataset exists:", dataset_dir.exists())
print("Dataset path:", dataset_dir)
# Out:
# Working directory: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si
# Dataset exists: True
# Dataset path: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/Hard Hat Sample.v2-augmented-416x416.voc

# %%
# Ejecuta el script principal
# !python mediapipe_quan_simple.py
# Out:
# 2025-11-24 10:52:46.994541: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-24 10:52:46.994570: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-24 10:52:47.002423: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-24 10:52:48.486181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
