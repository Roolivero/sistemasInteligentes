# %% [markdown]
# # Entrenar y cuantizar con MediaPipe Model Maker
#
# Ejecuta el script `mediapipe_quan_simple.py` desde este notebook, usando las rutas relativas del proyecto.

# %%
import os
from pathlib import Path

# Ajusta el directorio de trabajo al del notebook/script
PROJECT_ROOT = Path(__file__).resolve().parent if "__file__" in globals() else Path().resolve()
os.chdir(PROJECT_ROOT)
print("Working directory:", Path.cwd())

# Opcional: valida que el dataset esté donde el script lo espera
dataset_dir = PROJECT_ROOT / "Hard Hat Sample.v2-augmented-416x416.voc"
print("Dataset exists:", dataset_dir.exists())
print("Dataset path:", dataset_dir)
# Out:
# Working directory: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si
# Dataset exists: True
# Dataset path: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/Hard Hat Sample.v2-augmented-416x416.voc

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
print("GPUs disponibles:", gpus)
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    tf.debugging.set_log_device_placement(True)
    print("Log de colocación de dispositivos activado.")
else:
    print("No se detectó GPU; se usará CPU.")
# Out:
# 2025-11-26 21:30:09.848776: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-26 21:30:09.848808: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-26 21:30:09.848833: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-26 21:30:09.854649: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Log de colocación de dispositivos activado.
# 2025-11-26 21:30:27.987210: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-26 21:30:28.672085: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-26 21:30:28.675453: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# Ejecuta el script principal
# !python mediapipe_quan_simple.py
# Out:
# 2025-11-26 21:30:29.064628: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-26 21:30:29.064674: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-26 21:30:29.064706: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# /mnt/sda1/code/si/ProyectoRedesNeuronales/.venv/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Creando estructura de cache...
# Cargando dataset...
# Train dataset cargado
# Val dataset cargado
# Clases: ['background', 'head', 'helmet', 'person']
#
# === PASO 1: Entrenando modelo FLOAT ===
# Using existing files at /tmp/model_maker/object_detector/mobilenetv2_i256
# Model: "retina_net_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net (MobileNet)      {'2': (None, 64, 64, 24   2257984
#                              ),
#                               '3': (None, 32, 32, 32
#                              ),
#                               '4': (None, 16, 16, 96
#                              ),
#                               '5': (None, 8, 8, 320)
#                              , '6': (None, 8, 8, 128
#                              0)}
#
#  fpn (FPN)                   {'5': (None, 8, 8, 128)   149056
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator (MultilevelDetectionG
#  enerator)
#
#  retina_net_head (RetinaNet  ({'3': (None, 32, 32, 3   173384
#  Head)                       6),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 2580424 (9.84 MB)
# Trainable params: 2534792 (9.67 MB)
# Non-trainable params: 45632 (178.25 KB)
# _________________________________________________________________
# Epoch 1/20
# 26/26 [==============================] - 58s 426ms/step - total_loss: 2.7100 - cls_loss: 2.1421 - box_loss: 0.0103 - model_loss: 2.6551 - val_total_loss: 1.4467 - val_cls_loss: 1.1047 - val_box_loss: 0.0057 - val_model_loss: 1.3917
# Epoch 2/20
# 26/26 [==============================] - 5s 189ms/step - total_loss: 1.3630 - cls_loss: 0.9590 - box_loss: 0.0070 - model_loss: 1.3080 - val_total_loss: 1.0554 - val_cls_loss: 0.7787 - val_box_loss: 0.0044 - val_model_loss: 1.0004
# Epoch 3/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.9455 - cls_loss: 0.6417 - box_loss: 0.0050 - model_loss: 0.8905 - val_total_loss: 0.8405 - val_cls_loss: 0.5856 - val_box_loss: 0.0040 - val_model_loss: 0.7855
# Epoch 4/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.7842 - cls_loss: 0.5050 - box_loss: 0.0045 - model_loss: 0.7292 - val_total_loss: 0.7593 - val_cls_loss: 0.5118 - val_box_loss: 0.0039 - val_model_loss: 0.7043
# Epoch 5/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.6812 - cls_loss: 0.4386 - box_loss: 0.0038 - model_loss: 0.6262 - val_total_loss: 0.6969 - val_cls_loss: 0.4680 - val_box_loss: 0.0035 - val_model_loss: 0.6420
# Epoch 6/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.6211 - cls_loss: 0.3919 - box_loss: 0.0035 - model_loss: 0.5661 - val_total_loss: 0.6529 - val_cls_loss: 0.4225 - val_box_loss: 0.0035 - val_model_loss: 0.5979
# Epoch 7/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.5927 - cls_loss: 0.3751 - box_loss: 0.0033 - model_loss: 0.5378 - val_total_loss: 0.6045 - val_cls_loss: 0.3919 - val_box_loss: 0.0032 - val_model_loss: 0.5495
# Epoch 8/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.5455 - cls_loss: 0.3364 - box_loss: 0.0031 - model_loss: 0.4905 - val_total_loss: 0.5930 - val_cls_loss: 0.3692 - val_box_loss: 0.0034 - val_model_loss: 0.5380
# Epoch 9/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.4977 - cls_loss: 0.3023 - box_loss: 0.0028 - model_loss: 0.4427 - val_total_loss: 0.5901 - val_cls_loss: 0.3579 - val_box_loss: 0.0035 - val_model_loss: 0.5351
# Epoch 10/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.5292 - cls_loss: 0.3271 - box_loss: 0.0029 - model_loss: 0.4742 - val_total_loss: 0.6128 - val_cls_loss: 0.3537 - val_box_loss: 0.0041 - val_model_loss: 0.5578
# Epoch 11/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.4669 - cls_loss: 0.2858 - box_loss: 0.0025 - model_loss: 0.4119 - val_total_loss: 0.5630 - val_cls_loss: 0.3353 - val_box_loss: 0.0035 - val_model_loss: 0.5080
# Epoch 12/20
# 26/26 [==============================] - 5s 192ms/step - total_loss: 0.4511 - cls_loss: 0.2741 - box_loss: 0.0024 - model_loss: 0.3961 - val_total_loss: 0.5757 - val_cls_loss: 0.3306 - val_box_loss: 0.0038 - val_model_loss: 0.5207
# Epoch 13/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.4295 - cls_loss: 0.2591 - box_loss: 0.0023 - model_loss: 0.3745 - val_total_loss: 0.5506 - val_cls_loss: 0.3139 - val_box_loss: 0.0036 - val_model_loss: 0.4956
# Epoch 14/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.4218 - cls_loss: 0.2505 - box_loss: 0.0023 - model_loss: 0.3668 - val_total_loss: 0.5818 - val_cls_loss: 0.3186 - val_box_loss: 0.0042 - val_model_loss: 0.5268
# Epoch 15/20
# 26/26 [==============================] - 5s 190ms/step - total_loss: 0.4368 - cls_loss: 0.2605 - box_loss: 0.0024 - model_loss: 0.3818 - val_total_loss: 0.5727 - val_cls_loss: 0.3187 - val_box_loss: 0.0040 - val_model_loss: 0.5177
# Epoch 16/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.3918 - cls_loss: 0.2320 - box_loss: 0.0021 - model_loss: 0.3368 - val_total_loss: 0.5788 - val_cls_loss: 0.3190 - val_box_loss: 0.0041 - val_model_loss: 0.5238
# Epoch 17/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.4024 - cls_loss: 0.2388 - box_loss: 0.0022 - model_loss: 0.3474 - val_total_loss: 0.5520 - val_cls_loss: 0.3160 - val_box_loss: 0.0036 - val_model_loss: 0.4970
# Epoch 18/20
# 26/26 [==============================] - 5s 192ms/step - total_loss: 0.3909 - cls_loss: 0.2324 - box_loss: 0.0021 - model_loss: 0.3359 - val_total_loss: 0.5399 - val_cls_loss: 0.3144 - val_box_loss: 0.0034 - val_model_loss: 0.4849
# Epoch 19/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.3987 - cls_loss: 0.2352 - box_loss: 0.0022 - model_loss: 0.3438 - val_total_loss: 0.5543 - val_cls_loss: 0.3090 - val_box_loss: 0.0038 - val_model_loss: 0.4993
# Epoch 20/20
# 26/26 [==============================] - 5s 191ms/step - total_loss: 0.3570 - cls_loss: 0.2086 - box_loss: 0.0019 - model_loss: 0.3020 - val_total_loss: 0.5455 - val_cls_loss: 0.3082 - val_box_loss: 0.0036 - val_model_loss: 0.4905
#
# Evaluando modelo float...
# 20/20 [==============================] - 1s 14ms/step - total_loss: 0.5720 - cls_loss: 0.3280 - box_loss: 0.0038 - model_loss: 0.5170
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.35s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.574
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.728
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
# Float model - Loss:  [0.5719953775405884, 0.32796239852905273, 0.0037812076043337584, 0.5170227885246277]
# Métricas: {'AP': 0.28583014, 'AP50': 0.57413256, 'AP75': 0.2133554, 'APs': 0.2058535, 'APm': 0.29723173, 'APl': 0.7280528, 'ARmax1': 0.09111111, 'ARmax10': 0.33037037, 'ARmax100': 0.3448148, 'ARs': 0.23333333, 'ARm': 0.35777777, 'ARl': 0.75}
#   AP: 0.28583014011383057
#   AP50: 0.5741325616836548
#   AP75: 0.2133554071187973
#   APs: 0.20585350692272186
#   APm: 0.2972317337989807
#   APl: 0.7280527949333191
#   ARmax1: 0.09111110866069794
#   ARmax10: 0.33037036657333374
#   ARmax100: 0.34481480717658997
#   ARs: 0.23333333432674408
#   ARm: 0.35777777433395386
#   ARl: 0.75
# Exporting a floating point model
# 2025-11-26 21:34:41.092200: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-26 21:34:41.092226: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# Modelo float exportado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_float/model_float.tflite
#
# === PASO 2: Quantization Aware Training ===
# Restaurando checkpoint float...
# Using existing files at /tmp/model_maker/object_detector/mobilenetv2_i256
# Model: "retina_net_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobile_net_1 (MobileNet)    {'2': (None, 64, 64, 24   2257984
#                              ),
#                               '3': (None, 32, 32, 32
#                              ),
#                               '4': (None, 16, 16, 96
#                              ),
#                               '5': (None, 8, 8, 320)
#                              , '6': (None, 8, 8, 128
#                              0)}
#
#  fpn_1 (FPN)                 {'5': (None, 8, 8, 128)   149056
#                              , '4': (None, 16, 16, 1
#                              28),
#                               '3': (None, 32, 32, 12
#                              8),
#                               '6': (None, 4, 4, 128)
#                              , '7': (None, 2, 2, 128
#                              )}
#
#  multilevel_detection_gener  multiple                  0 (unused)
#  ator_2 (MultilevelDetectio
#  nGenerator)
#
#  retina_net_head_1 (RetinaN  ({'3': (None, 32, 32, 3   173384
#  etHead)                     6),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {'3': (None, 32, 32,
#                              36),
#                               '4': (None, 16, 16, 36
#                              ),
#                               '5': (None, 8, 8, 36),
#                               '6': (None, 4, 4, 36),
#                               '7': (None, 2, 2, 36)}
#                              , {})
#
# =================================================================
# Total params: 2580424 (9.84 MB)
# Trainable params: 2534792 (9.67 MB)
# Non-trainable params: 45632 (178.25 KB)
# _________________________________________________________________
# Iniciando QAT...
# Epoch 1/20
# 52/52 [==============================] - 85s 441ms/step - total_loss: 1.7241 - cls_loss: 0.8552 - box_loss: 0.0174 - model_loss: 1.7241 - val_total_loss: 2.2349 - val_cls_loss: 1.5153 - val_box_loss: 0.0144 - val_model_loss: 2.2349
# Epoch 2/20
# 52/52 [==============================] - 15s 291ms/step - total_loss: 1.0171 - cls_loss: 0.5957 - box_loss: 0.0084 - model_loss: 1.0171 - val_total_loss: 1.8135 - val_cls_loss: 1.2638 - val_box_loss: 0.0110 - val_model_loss: 1.8135
# Epoch 3/20
# 52/52 [==============================] - 15s 292ms/step - total_loss: 0.8620 - cls_loss: 0.5222 - box_loss: 0.0068 - model_loss: 0.8620 - val_total_loss: 1.5445 - val_cls_loss: 1.1016 - val_box_loss: 0.0089 - val_model_loss: 1.5445
# Epoch 4/20
# 52/52 [==============================] - 15s 292ms/step - total_loss: 0.8255 - cls_loss: 0.4985 - box_loss: 0.0065 - model_loss: 0.8255 - val_total_loss: 1.3510 - val_cls_loss: 0.9729 - val_box_loss: 0.0076 - val_model_loss: 1.3510
# Epoch 5/20
# 52/52 [==============================] - 15s 291ms/step - total_loss: 0.7638 - cls_loss: 0.4627 - box_loss: 0.0060 - model_loss: 0.7638 - val_total_loss: 1.1917 - val_cls_loss: 0.8393 - val_box_loss: 0.0070 - val_model_loss: 1.1917
# Epoch 6/20
# 52/52 [==============================] - 15s 291ms/step - total_loss: 0.7604 - cls_loss: 0.4602 - box_loss: 0.0060 - model_loss: 0.7604 - val_total_loss: 1.0369 - val_cls_loss: 0.7035 - val_box_loss: 0.0067 - val_model_loss: 1.0369
# Epoch 7/20
# 52/52 [==============================] - 15s 293ms/step - total_loss: 0.7182 - cls_loss: 0.4389 - box_loss: 0.0056 - model_loss: 0.7182 - val_total_loss: 0.9347 - val_cls_loss: 0.6089 - val_box_loss: 0.0065 - val_model_loss: 0.9347
# Epoch 8/20
# 52/52 [==============================] - 15s 294ms/step - total_loss: 0.7291 - cls_loss: 0.4443 - box_loss: 0.0057 - model_loss: 0.7291 - val_total_loss: 0.8462 - val_cls_loss: 0.5354 - val_box_loss: 0.0062 - val_model_loss: 0.8462
# Epoch 9/20
# 52/52 [==============================] - 15s 291ms/step - total_loss: 0.7448 - cls_loss: 0.4522 - box_loss: 0.0059 - model_loss: 0.7448 - val_total_loss: 0.7952 - val_cls_loss: 0.4888 - val_box_loss: 0.0061 - val_model_loss: 0.7952
# Epoch 10/20
# 52/52 [==============================] - 15s 292ms/step - total_loss: 0.6814 - cls_loss: 0.4183 - box_loss: 0.0053 - model_loss: 0.6814 - val_total_loss: 0.7770 - val_cls_loss: 0.4721 - val_box_loss: 0.0061 - val_model_loss: 0.7770
# Epoch 11/20
# 52/52 [==============================] - 15s 293ms/step - total_loss: 0.7024 - cls_loss: 0.4283 - box_loss: 0.0055 - model_loss: 0.7024 - val_total_loss: 0.7531 - val_cls_loss: 0.4542 - val_box_loss: 0.0060 - val_model_loss: 0.7531
# Epoch 12/20
# 52/52 [==============================] - 15s 293ms/step - total_loss: 0.6794 - cls_loss: 0.4162 - box_loss: 0.0053 - model_loss: 0.6794 - val_total_loss: 0.7461 - val_cls_loss: 0.4474 - val_box_loss: 0.0060 - val_model_loss: 0.7461
# Epoch 13/20
# 52/52 [==============================] - 15s 295ms/step - total_loss: 0.6699 - cls_loss: 0.4129 - box_loss: 0.0051 - model_loss: 0.6699 - val_total_loss: 0.7547 - val_cls_loss: 0.4497 - val_box_loss: 0.0061 - val_model_loss: 0.7547
# Epoch 14/20
# 52/52 [==============================] - 15s 292ms/step - total_loss: 0.6591 - cls_loss: 0.4017 - box_loss: 0.0051 - model_loss: 0.6591 - val_total_loss: 0.7502 - val_cls_loss: 0.4506 - val_box_loss: 0.0060 - val_model_loss: 0.7502
# Epoch 15/20
# 52/52 [==============================] - 15s 291ms/step - total_loss: 0.6909 - cls_loss: 0.4204 - box_loss: 0.0054 - model_loss: 0.6909 - val_total_loss: 0.7450 - val_cls_loss: 0.4433 - val_box_loss: 0.0060 - val_model_loss: 0.7450
# Epoch 16/20
# 52/52 [==============================] - 15s 293ms/step - total_loss: 0.6915 - cls_loss: 0.4222 - box_loss: 0.0054 - model_loss: 0.6915 - val_total_loss: 0.7459 - val_cls_loss: 0.4492 - val_box_loss: 0.0059 - val_model_loss: 0.7459
# Epoch 17/20
# 52/52 [==============================] - 15s 293ms/step - total_loss: 0.6848 - cls_loss: 0.4173 - box_loss: 0.0054 - model_loss: 0.6848 - val_total_loss: 0.7479 - val_cls_loss: 0.4467 - val_box_loss: 0.0060 - val_model_loss: 0.7479
# Epoch 18/20
# 52/52 [==============================] - 15s 295ms/step - total_loss: 0.6920 - cls_loss: 0.4202 - box_loss: 0.0054 - model_loss: 0.6920 - val_total_loss: 0.7446 - val_cls_loss: 0.4484 - val_box_loss: 0.0059 - val_model_loss: 0.7446
# Epoch 19/20
# 52/52 [==============================] - 15s 294ms/step - total_loss: 0.6663 - cls_loss: 0.4099 - box_loss: 0.0051 - model_loss: 0.6663 - val_total_loss: 0.7497 - val_cls_loss: 0.4500 - val_box_loss: 0.0060 - val_model_loss: 0.7497
# Epoch 20/20
# 52/52 [==============================] - 15s 293ms/step - total_loss: 0.7134 - cls_loss: 0.4341 - box_loss: 0.0056 - model_loss: 0.7134 - val_total_loss: 0.7515 - val_cls_loss: 0.4504 - val_box_loss: 0.0060 - val_model_loss: 0.7515
#
# Evaluando modelo cuantizado...
# 20/20 [==============================] - 2s 61ms/step - total_loss: 0.7493 - cls_loss: 0.4569 - box_loss: 0.0058 - model_loss: 0.7493
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.339
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.667
# QAT model - Loss:  [0.7492769956588745, 0.45691075921058655, 0.005847323685884476, 0.7492769956588745]
# Métricas: {'AP': 0.1474523, 'AP50': 0.40277562, 'AP75': 0.06697008, 'APs': 0.09991513, 'APm': 0.17141522, 'APl': 0.65658414, 'ARmax1': 0.117037036, 'ARmax10': 0.30666667, 'ARmax100': 0.33925927, 'ARs': 0.12222222, 'ARm': 0.35222223, 'ARl': 0.6666667}
#
# Exportando modelo cuantizado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_qat.tflite
# Exporting a qat int8 model
# 2025-11-26 21:42:49.982554: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-11-26 21:42:49.982581: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# ¡Entrenamiento completo!
#
# Resumen:
# - Modelo float: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_float/model_float.tflite
# - Modelo cuantizado: /mnt/sda1/code/si/ProyectoRedesNeuronales/redes_neuronales_si/models/mobilenet_v2_qat.tflite
